# %% [markdown]
# # Data Mining Week 11 with Professor Sloan
#
# ## Maggie Boles
#
# ### 11/17/2025
#
# ### From Blackboard: Using the tweets.csv dataset from Week 3, use pattern matching to find every term that can be categorized as “SOCIAL_CAUSE”. Your result should be a Pandas DataFrame that contains the following information (the DataFrame can be very simple or very nice – that’s up to you):
#     Author	Matched Text	Identifier
#     katyperry	power to the people	SOCIAL_CAUSE
#     BarackOba	roll back poverty	SOCIAL_CAUSE
#     rihanna	people ov venezuala in your prayers	SOCIAL_CAUSE
#     Note that the table above is just a small sample – you can match on as many terms as you want, but your code must leverage:
#     Matcher
#     PhraseMatcher (at least once)
#     on_match callback (at least one)
#     Matches on more than just specific text – use POS, IS_PUNCT or any other token attributes (for no less than one match pattern, but I encourage you to use other token attributes often since this is the real power of spaCy pattern matching)
#     Regular expression (at least once)
#     Note that the beauty of this Python package is that you define what a SOCIAL_CAUSE is, explicitly, using the text as your guide. This feature is especially important when dealing with domain-specific corpora, since the language is not simply Wikipedia data.

# %%
#import libraries
import pandas as pd
import spacy
from spacy.matcher import Matcher, PhraseMatcher
from spacy.tokens import Doc

# 1. Load the data + model

df = pd.read_csv("twitter_sample.csv")   # your file
nlp = spacy.load("en_core_web_sm")

# Register custom extension for callback
Doc.set_extension("author", default="unknown", force=True)

results = []

# 2. on_match callback 
def add_match(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start:end]
    results.append({
        "Author": doc._.author,
        "Matched Text": span.text,
        "Identifier": "SOCIAL_CAUSE"
    })

# 3. Matchers — tailored to the actual data

matcher = Matcher(nlp.vocab)
phrase_matcher = PhraseMatcher(nlp.vocab, attr="LOWER")

# PhraseMatcher: real phrases in the dataset 
phrases = [
    "#morethanmedicine", "more than medicine", "morethanmedicine",
    "#animalhealthmatters", "animal health matters",
    "#petsarefamily", "pets are family",
    "#animalhealth", "animal medicines", "animal welfare"
]
phrase_patterns = [nlp.make_doc(p) for p in phrases]
phrase_matcher.add("ANIMAL_HEALTH_CAMPAIGN", phrase_patterns)

# --- Matcher: advanced patterns that match ---
matcher.add("HASHTAG", [[{"TEXT": {"REGEX": "^#.*"}}]])  # any hashtag

matcher.add("POWERFUL_PHRASE", [[
    {"LOWER": "more"}, {"LOWER": "than"}, {"LOWER": "medicine"}
]], on_match=add_match)  # ← callback triggers here!

matcher.add("ANIMAL_HEALTH", [[
    {"LEMMA": {"IN": ["animal", "pet", "veterinary"]}},
    {"LEMMA": {"IN": ["health", "medicine", "welfare"]}}
]])

matcher.add("THANKS_MENTION", [[
    {"LOWER": "thank"}, {"IS_ALPHA": True, "OP": "?"}, 
    {"LOWER": "you"}, {"IS_PUNCT": True, "OP": "?"},
    {"TEXT": {"REGEX": "^@.*"}}
]])

# 4. Process each tweet using the columns

for _, row in df.iterrows():
    tweet = str(row["Tweet Content"])
    author = str(row["Username"])
    
    # Clean up common Twitter junk
    tweet = tweet.replace("&amp;", "&")
    
    if not tweet.strip() or tweet.lower() == "nan":
        continue

    doc = nlp(tweet)
    doc._.author = author

    # Run matchers
    matcher(doc)        # ← callback fires!
    phrase_matches = phrase_matcher(doc)

    # Collect PhraseMatcher results
    for match_id, start, end in phrase_matches:
        span = doc[start:end]
        results.append({
            "Author": author,
            "Matched Text": span.text,
            "Identifier": "SOCIAL_CAUSE"
        })


# 5. Results as a DataFrame
result_df = pd.DataFrame(results)

if not result_df.empty:
    result_df = (result_df
                 .drop_duplicates()
                 .sort_values(["Author", "Matched Text"])
                 .reset_index(drop=True))
    print(f"\nFOUND {len(result_df)} SOCIAL_CAUSE MATCHES! (All about #MorethanMedicine)\n")
else:
    result_df = pd.DataFrame(columns=["Author", "Matched Text", "Identifier"])
    print("No matches — something went wrong")

print(result_df.to_string(index=False))
result_df
# Out:
# FOUND 390 SOCIAL_CAUSE MATCHES! (All about #MorethanMedicine)
#
#          Author         Matched Text   Identifier
#         ACEPNow    #MoreThanMedicine SOCIAL_CAUSE
#         ACEPNow     MoreThanMedicine SOCIAL_CAUSE
#        ACNANSI1    #MorethanMedicine SOCIAL_CAUSE
#        ACNANSI1     MorethanMedicine SOCIAL_CAUSE
#        ACOEPRSO    #MoreThanMedicine SOCIAL_CAUSE
#        ACOEPRSO     MoreThanMedicine SOCIAL_CAUSE
#         AG_EM33    #MoreThanMedicine SOCIAL_CAUSE
#         AG_EM33     MoreThanMedicine SOCIAL_CAUSE
#       ALLOhioEM    #MoreThanMedicine SOCIAL_CAUSE
#       ALLOhioEM     MoreThanMedicine SOCIAL_CAUSE
#  AgedeGuillaume    #MorethanMedicine SOCIAL_CAUSE
#  AgedeGuillaume     MorethanMedicine SOCIAL_CAUSE
#    Agri_Updates    #MorethanMedicine SOCIAL_CAUSE
#    Agri_Updates        #animalhealth SOCIAL_CAUSE
#    Agri_Updates     MorethanMedicine SOCIAL_CAUSE
#    Al3xCarvalho    #MorethanMedicine SOCIAL_CAUSE
#    Al3xCarvalho     MorethanMedicine SOCIAL_CAUSE
#    Al3xCarvalho       animal welfare SOCIAL_CAUSE
#   Alex_KamskyEM    #MoreThanMedicine SOCIAL_CAUSE
#   Alex_KamskyEM     MoreThanMedicine SOCIAL_CAUSE
#      AliRaja_MD    #MoreThanMedicine SOCIAL_CAUSE
#      AliRaja_MD     MoreThanMedicine SOCIAL_CAUSE
#  AlisonBevanRWA    #morethanmedicine SOCIAL_CAUSE
#  AlisonBevanRWA     morethanmedicine SOCIAL_CAUSE
#      Alvanleyfp    #morethanmedicine SOCIAL_CAUSE
#      Alvanleyfp     morethanmedicine SOCIAL_CAUSE
#  AndreaWestbyMD    #morethanmedicine SOCIAL_CAUSE
#  AndreaWestbyMD     morethanmedicine SOCIAL_CAUSE
# Angelik01017077    #MorethanMedicine SOCIAL_CAUSE
# Angelik01017077     MorethanMedicine SOCIAL_CAUSE
#   Bayer4Animals    #MorethanMedicine SOCIAL_CAUSE
#   Bayer4Animals        #animalhealth SOCIAL_CAUSE
#   Bayer4Animals     Animal medicines SOCIAL_CAUSE
#   Bayer4Animals     MorethanMedicine SOCIAL_CAUSE
#      BfTGermany #AnimalHealthMatters SOCIAL_CAUSE
#      BfTGermany    #MorethanMedicine SOCIAL_CAUSE
#      BfTGermany       #PetsareFamily SOCIAL_CAUSE
#      BfTGermany     MorethanMedicine SOCIAL_CAUSE
#   Boehringer_AH        #AnimalHealth SOCIAL_CAUSE
#   Boehringer_AH    #MorethanMedicine SOCIAL_CAUSE
#   Boehringer_AH     MorethanMedicine SOCIAL_CAUSE
#    BrusselsGeek    #MorethanMedicine SOCIAL_CAUSE
#    BrusselsGeek     MorethanMedicine SOCIAL_CAUSE
#      BvmLaurien    #MorethanMedicine SOCIAL_CAUSE
#      BvmLaurien     MorethanMedicine SOCIAL_CAUSE
#        CEO_PBUK    #morethanmedicine SOCIAL_CAUSE
#        CEO_PBUK     morethanmedicine SOCIAL_CAUSE
#        CHBlades    #morethanmedicine SOCIAL_CAUSE
#        CHBlades     morethanmedicine SOCIAL_CAUSE
#        CHCR_UWE    #morethanmedicine SOCIAL_CAUSE
#        CHCR_UWE     morethanmedicine SOCIAL_CAUSE
#       CaitrinaH    #MorethanMedicine SOCIAL_CAUSE
#       CaitrinaH     MorethanMedicine SOCIAL_CAUSE
# CevaSanteAnimal    #MorethanMedicine SOCIAL_CAUSE
# CevaSanteAnimal     MorethanMedicine SOCIAL_CAUSE
#    CheriCheri40    #morethanmedicine SOCIAL_CAUSE
#    CheriCheri40     morethanmedicine SOCIAL_CAUSE
#      CoBellevue    #MoreThanMedicine SOCIAL_CAUSE
#      CoBellevue     MoreThanMedicine SOCIAL_CAUSE
#   CountessDavis    #morethanmedicine SOCIAL_CAUSE
#   CountessDavis     morethanmedicine SOCIAL_CAUSE
#        CytonBio    #MorethanMedicine SOCIAL_CAUSE
#        CytonBio        #animalhealth SOCIAL_CAUSE
#        CytonBio     MorethanMedicine SOCIAL_CAUSE
# DCHospitalAssoc    #MoreThanMedicine SOCIAL_CAUSE
# DCHospitalAssoc     MoreThanMedicine SOCIAL_CAUSE
#     DocWillisMD    #MoreThanMedicine SOCIAL_CAUSE
#     DocWillisMD     MoreThanMedicine SOCIAL_CAUSE
#    DoctorsEMres    #MoreThanMedicine SOCIAL_CAUSE
#    DoctorsEMres     MoreThanMedicine SOCIAL_CAUSE
#        Dopharma    #MorethanMedicine SOCIAL_CAUSE
#        Dopharma        #animalhealth SOCIAL_CAUSE
#        Dopharma     MorethanMedicine SOCIAL_CAUSE
#    DrAlbertPoon    #morethanmedicine SOCIAL_CAUSE
#    DrAlbertPoon     morethanmedicine SOCIAL_CAUSE
#     DrRobinPaul    #MorethanMedicine SOCIAL_CAUSE
#     DrRobinPaul     Animal medicines SOCIAL_CAUSE
#     DrRobinPaul     MorethanMedicine SOCIAL_CAUSE
#      EKrepinska    #MorethanMedicine SOCIAL_CAUSE
#      EKrepinska        #animalhealth SOCIAL_CAUSE
#      EKrepinska     MorethanMedicine SOCIAL_CAUSE
#      EMOverEasy    #MoreThanMedicine SOCIAL_CAUSE
#      EMOverEasy     MoreThanMedicine SOCIAL_CAUSE
#       EMinMiami    #morethanmedicine SOCIAL_CAUSE
#       EMinMiami     morethanmedicine SOCIAL_CAUSE
#        ElancoEU    #MorethanMedicine SOCIAL_CAUSE
#        ElancoEU        #animalhealth SOCIAL_CAUSE
#        ElancoEU     Animal medicines SOCIAL_CAUSE
#        ElancoEU     MorethanMedicine SOCIAL_CAUSE
#        ElancoEU       animal welfare SOCIAL_CAUSE
#   ErikFDeRidder    #MorethanMedicine SOCIAL_CAUSE
#   ErikFDeRidder        #animalhealth SOCIAL_CAUSE
#   ErikFDeRidder     MorethanMedicine SOCIAL_CAUSE
#  Fiona_C_Taylor    #morethanmedicine SOCIAL_CAUSE
#  Fiona_C_Taylor     morethanmedicine SOCIAL_CAUSE
#     FltDocRoars    #MoreThanMedicine SOCIAL_CAUSE
#     FltDocRoars     MoreThanMedicine SOCIAL_CAUSE
#    GetWellGetOn    #morethanmedicine SOCIAL_CAUSE
#    GetWellGetOn     morethanmedicine SOCIAL_CAUSE
# GezijtvanTonger    #MorethanMedicine SOCIAL_CAUSE
# GezijtvanTonger        #animalhealth SOCIAL_CAUSE
# GezijtvanTonger     MorethanMedicine SOCIAL_CAUSE
#    GordonChung6    #MorethanMedicine SOCIAL_CAUSE
#    GordonChung6     MorethanMedicine SOCIAL_CAUSE
#    HolmesHaddad    #morethanmedicine SOCIAL_CAUSE
#    HolmesHaddad     morethanmedicine SOCIAL_CAUSE
#     HoyeKristof    #MorethanMedicine SOCIAL_CAUSE
#     HoyeKristof     MorethanMedicine SOCIAL_CAUSE
#     HoyeKristof       animal welfare SOCIAL_CAUSE
#          Hylkie    #MoreThanMedicine SOCIAL_CAUSE
#          Hylkie     MoreThanMedicine SOCIAL_CAUSE
#       IanMWelsh    #MorethanMedicine SOCIAL_CAUSE
#       IanMWelsh     MorethanMedicine SOCIAL_CAUSE
#   IheartmypetUK    #MorethanMedicine SOCIAL_CAUSE
#   IheartmypetUK        #animalhealth SOCIAL_CAUSE
#   IheartmypetUK     MorethanMedicine SOCIAL_CAUSE
#   IheartmypetUK       animal welfare SOCIAL_CAUSE
#   JamieBrannan1    #MorethanMedicine SOCIAL_CAUSE
#   JamieBrannan1        #animalhealth SOCIAL_CAUSE
#   JamieBrannan1     MorethanMedicine SOCIAL_CAUSE
#   JamieBrannan1       animal welfare SOCIAL_CAUSE
#     JulieADMVdC    #MorethanMedicine SOCIAL_CAUSE
#     JulieADMVdC     MorethanMedicine SOCIAL_CAUSE
#     JulieADMVdC       animal welfare SOCIAL_CAUSE
#      K8Forester    #MorethanMedicine SOCIAL_CAUSE
#      K8Forester        #animalhealth SOCIAL_CAUSE
#      K8Forester     MorethanMedicine SOCIAL_CAUSE
#    KPhillips_PA    #MoreThanMedicine SOCIAL_CAUSE
#    KPhillips_PA     MoreThanMedicine SOCIAL_CAUSE
#     LajosneVegh    #MorethanMedicine SOCIAL_CAUSE
#     LajosneVegh        #animalhealth SOCIAL_CAUSE
#     LajosneVegh     MorethanMedicine SOCIAL_CAUSE
#   LeighLeighj20    #morethanmedicine SOCIAL_CAUSE
#   LeighLeighj20     morethanmedicine SOCIAL_CAUSE
#   LesleyLesleys    #morethanmedicine SOCIAL_CAUSE
#   LesleyLesleys     morethanmedicine SOCIAL_CAUSE
#     LindsayGF96    #MoreThanMedicine SOCIAL_CAUSE
#     LindsayGF96     MoreThanMedicine SOCIAL_CAUSE
# ListensSusannah    #morethanmedicine SOCIAL_CAUSE
# ListensSusannah     morethanmedicine SOCIAL_CAUSE
#         Local12    #morethanmedicine SOCIAL_CAUSE
#         Local12     morethanmedicine SOCIAL_CAUSE
# MARIECH38201021    #MorethanMedicine SOCIAL_CAUSE
# MARIECH38201021     MorethanMedicine SOCIAL_CAUSE
#           MOX13    #MoreThanMedicine SOCIAL_CAUSE
#           MOX13     MoreThanMedicine SOCIAL_CAUSE
#        MRamzyDO    #MoreThanMedicine SOCIAL_CAUSE
#        MRamzyDO    #morethanmedicine SOCIAL_CAUSE
#        MRamzyDO     MoreThanMedicine SOCIAL_CAUSE
#        MRamzyDO     morethanmedicine SOCIAL_CAUSE
# MSDAnimalHealth    #MorethanMedicine SOCIAL_CAUSE
# MSDAnimalHealth        #animalhealth SOCIAL_CAUSE
# MSDAnimalHealth     MorethanMedicine SOCIAL_CAUSE
#    MarianNaidoo    #morethanmedicine SOCIAL_CAUSE
#    MarianNaidoo     morethanmedicine SOCIAL_CAUSE
#      MashBrown1    #MorethanMedicine SOCIAL_CAUSE
#      MashBrown1     MorethanMedicine SOCIAL_CAUSE
#    MatyldaStein    #MorethanMedicine SOCIAL_CAUSE
#    MatyldaStein     MorethanMedicine SOCIAL_CAUSE
#   MonitoringOur    #MorethanMedicine SOCIAL_CAUSE
#   MonitoringOur        #animalhealth SOCIAL_CAUSE
#   MonitoringOur     MorethanMedicine SOCIAL_CAUSE
# MuratKa56292467    #MorethanMedicine SOCIAL_CAUSE
# MuratKa56292467     MorethanMedicine SOCIAL_CAUSE
# MusicofTomHoffm    #morethanmedicine SOCIAL_CAUSE
# MusicofTomHoffm     morethanmedicine SOCIAL_CAUSE
#        OhioACEP    #MoreThanMedicine SOCIAL_CAUSE
#        OhioACEP     MoreThanMedicine SOCIAL_CAUSE
#       POLPROWET    #MoreThanMedicine SOCIAL_CAUSE
#       POLPROWET     MoreThanMedicine SOCIAL_CAUSE
#   PROactive2016    #morethanmedicine SOCIAL_CAUSE
#   PROactive2016     morethanmedicine SOCIAL_CAUSE
#    PennyBrohnUK    #morethanmedicine SOCIAL_CAUSE
#    PennyBrohnUK     morethanmedicine SOCIAL_CAUSE
#       PihokkerL    #MorethanMedicine SOCIAL_CAUSE
#       PihokkerL        #animalhealth SOCIAL_CAUSE
#       PihokkerL     MorethanMedicine SOCIAL_CAUSE
#        Pinhead6 #AnimalHealthMatters SOCIAL_CAUSE
#        Pinhead6    #MorethanMedicine SOCIAL_CAUSE
#        Pinhead6       #PetsareFamily SOCIAL_CAUSE
#        Pinhead6     MorethanMedicine SOCIAL_CAUSE
#     ProMammaDoc    #MoreThanMedicine SOCIAL_CAUSE
#     ProMammaDoc     MoreThanMedicine SOCIAL_CAUSE
#      RCNi_Julie    #morethanmedicine SOCIAL_CAUSE
#      RCNi_Julie     morethanmedicine SOCIAL_CAUSE
#         RE_PBUK    #morethanmedicine SOCIAL_CAUSE
#         RE_PBUK     morethanmedicine SOCIAL_CAUSE
#    RealZiggyFlo    #morethanmedicine SOCIAL_CAUSE
#    RealZiggyFlo     morethanmedicine SOCIAL_CAUSE
#         SIMV_RP    #MorethanMedicine SOCIAL_CAUSE
#         SIMV_RP        #animalhealth SOCIAL_CAUSE
#         SIMV_RP     MorethanMedicine SOCIAL_CAUSE
#     SidaiAfrica    #MorethanMedicine SOCIAL_CAUSE
#     SidaiAfrica     MorethanMedicine SOCIAL_CAUSE
#     Stingraytwo        #AnimalHealth SOCIAL_CAUSE
#     Stingraytwo    #MorethanMedicine SOCIAL_CAUSE
#     Stingraytwo     MorethanMedicine SOCIAL_CAUSE
#        The_EARA    #MorethanMedicine SOCIAL_CAUSE
#        The_EARA     MorethanMedicine SOCIAL_CAUSE
#         Tim_C66    #morethanmedicine SOCIAL_CAUSE
#         Tim_C66     morethanmedicine SOCIAL_CAUSE
#      TracyTait2    #morethanmedicine SOCIAL_CAUSE
#      TracyTait2     morethanmedicine SOCIAL_CAUSE
#        UCSF_CRC    #morethanmedicine SOCIAL_CAUSE
#        UCSF_CRC     morethanmedicine SOCIAL_CAUSE
#          UKNOAH    #MoreThanMedicine SOCIAL_CAUSE
#          UKNOAH    #MorethanMedicine SOCIAL_CAUSE
#          UKNOAH        #animalhealth SOCIAL_CAUSE
#          UKNOAH     MoreThanMedicine SOCIAL_CAUSE
#          UKNOAH     MorethanMedicine SOCIAL_CAUSE
#          UKNOAH       animal welfare SOCIAL_CAUSE
# USACS_Education    #MoreThanMedicine SOCIAL_CAUSE
# USACS_Education     MoreThanMedicine SOCIAL_CAUSE
#      Udahemuka1    #MorethanMedicine SOCIAL_CAUSE
#      Udahemuka1     MorethanMedicine SOCIAL_CAUSE
#     VetDocVideo #AnimalHealthMatters SOCIAL_CAUSE
#     VetDocVideo    #MorethanMedicine SOCIAL_CAUSE
#     VetDocVideo       #PetsareFamily SOCIAL_CAUSE
#     VetDocVideo     MorethanMedicine SOCIAL_CAUSE
#         Vetmasi    #MorethanMedicine SOCIAL_CAUSE
#         Vetmasi     Animal medicines SOCIAL_CAUSE
#         Vetmasi     MorethanMedicine SOCIAL_CAUSE
#    WK_Griffiths    #MorethanMedicine SOCIAL_CAUSE
#    WK_Griffiths     MorethanMedicine SOCIAL_CAUSE
#      YearofCare    #MorethanMedicine SOCIAL_CAUSE
#      YearofCare     MorethanMedicine SOCIAL_CAUSE
#      Yusuf_rid1    #MorethanMedicine SOCIAL_CAUSE
#      Yusuf_rid1     MorethanMedicine SOCIAL_CAUSE
#          Zoetis    #MorethanMedicine SOCIAL_CAUSE
#          Zoetis        #animalhealth SOCIAL_CAUSE
#          Zoetis     MorethanMedicine SOCIAL_CAUSE
#        afparron    #MorethanMedicine SOCIAL_CAUSE
#        afparron        #animalhealth SOCIAL_CAUSE
#        afparron #animalhealthmatters SOCIAL_CAUSE
#        afparron    #morethanmedicine SOCIAL_CAUSE
#        afparron     Animal medicines SOCIAL_CAUSE
#        afparron     MorethanMedicine SOCIAL_CAUSE
#        afparron     morethanmedicine SOCIAL_CAUSE
#   alkhalilkouma #AnimalHealthMatters SOCIAL_CAUSE
#   alkhalilkouma    #MorethanMedicine SOCIAL_CAUSE
#   alkhalilkouma        #animalhealth SOCIAL_CAUSE
#   alkhalilkouma     MorethanMedicine SOCIAL_CAUSE
#     andyglittle    #MoreThanMedicine SOCIAL_CAUSE
#     andyglittle     MoreThanMedicine SOCIAL_CAUSE
#  animalhealthEU        #AnimalHealth SOCIAL_CAUSE
#  animalhealthEU #AnimalHealthMatters SOCIAL_CAUSE
#  animalhealthEU    #MorethanMedicine SOCIAL_CAUSE
#  animalhealthEU       #PetsareFamily SOCIAL_CAUSE
#  animalhealthEU        #animalhealth SOCIAL_CAUSE
#  animalhealthEU #animalhealthmatters SOCIAL_CAUSE
#  animalhealthEU     Animal medicines SOCIAL_CAUSE
#  animalhealthEU     MorethanMedicine SOCIAL_CAUSE
#  animalhealthEU       animal welfare SOCIAL_CAUSE
#         bujaj49    #MoreThanMedicine SOCIAL_CAUSE
#         bujaj49     MoreThanMedicine SOCIAL_CAUSE
#      cathcooney    #MorethanMedicine SOCIAL_CAUSE
#      cathcooney     MorethanMedicine SOCIAL_CAUSE
#      catzollman    #morethanmedicine SOCIAL_CAUSE
#      catzollman     morethanmedicine SOCIAL_CAUSE
#         chao062    #MorethanMedicine SOCIAL_CAUSE
#         chao062     MorethanMedicine SOCIAL_CAUSE
#      charleskod    #morethanmedicine SOCIAL_CAUSE
#      charleskod     morethanmedicine SOCIAL_CAUSE
#         cjwazzy    #MoreThanMedicine SOCIAL_CAUSE
#         cjwazzy     MoreThanMedicine SOCIAL_CAUSE
#   colmevetchile    #MorethanMedicine SOCIAL_CAUSE
#   colmevetchile     MorethanMedicine SOCIAL_CAUSE
#   colmevetchile       animal welfare SOCIAL_CAUSE
#  crystaltipps24    #morethanmedicine SOCIAL_CAUSE
#  crystaltipps24     morethanmedicine SOCIAL_CAUSE
#         dkalnow    #MoreThanMedicine SOCIAL_CAUSE
#         dkalnow    #morethanmedicine SOCIAL_CAUSE
#         dkalnow     MoreThanMedicine SOCIAL_CAUSE
#         dkalnow     morethanmedicine SOCIAL_CAUSE
#     drshahrul80    #MoreThanMedicine SOCIAL_CAUSE
#     drshahrul80     MoreThanMedicine SOCIAL_CAUSE
#  eileenthecoast    #MorethanMedicine SOCIAL_CAUSE
#  eileenthecoast        #animalhealth SOCIAL_CAUSE
#  eileenthecoast     MorethanMedicine SOCIAL_CAUSE
#   emmabeeston01    #morethanmedicine SOCIAL_CAUSE
#   emmabeeston01     morethanmedicine SOCIAL_CAUSE
#     emresidents    #MoreThanMedicine SOCIAL_CAUSE
#     emresidents     MoreThanMedicine SOCIAL_CAUSE
#   erzsebetdeak3    #MorethanMedicine SOCIAL_CAUSE
#   erzsebetdeak3        #animalhealth SOCIAL_CAUSE
#   erzsebetdeak3     MorethanMedicine SOCIAL_CAUSE
#        ffolliet    #MoreThanMedicine SOCIAL_CAUSE
#        ffolliet     MoreThanMedicine SOCIAL_CAUSE
#       gelen1974    #MorethanMedicine SOCIAL_CAUSE
#       gelen1974     MorethanMedicine SOCIAL_CAUSE
#        gknutson    #morethanmedicine SOCIAL_CAUSE
#        gknutson     morethanmedicine SOCIAL_CAUSE
#      habdevoogd    #MorethanMedicine SOCIAL_CAUSE
#      habdevoogd        #animalhealth SOCIAL_CAUSE
#      habdevoogd     MorethanMedicine SOCIAL_CAUSE
#      habdevoogd       animal welfare SOCIAL_CAUSE
#     hackneywick    #morethanmedicine SOCIAL_CAUSE
#     hackneywick     morethanmedicine SOCIAL_CAUSE
#       hanyshita    #MorethanMedicine SOCIAL_CAUSE
#       hanyshita        #animalhealth SOCIAL_CAUSE
#       hanyshita     MorethanMedicine SOCIAL_CAUSE
#       hanyshita       animal welfare SOCIAL_CAUSE
#    higenyijames    #MorethanMedicine SOCIAL_CAUSE
#    higenyijames     MorethanMedicine SOCIAL_CAUSE
#    iamKhalifa98    #MorethanMedicine SOCIAL_CAUSE
#    iamKhalifa98        #animalhealth SOCIAL_CAUSE
#    iamKhalifa98     MorethanMedicine SOCIAL_CAUSE
#      inzerocent    #MorethanMedicine SOCIAL_CAUSE
#      inzerocent     MorethanMedicine SOCIAL_CAUSE
#     itsmathews_    #MorethanMedicine SOCIAL_CAUSE
#     itsmathews_     MorethanMedicine SOCIAL_CAUSE
#      karenellaB    #morethanmedicine SOCIAL_CAUSE
#      karenellaB     morethanmedicine SOCIAL_CAUSE
#   karin_stowell    #morethanmedicine SOCIAL_CAUSE
#   karin_stowell     morethanmedicine SOCIAL_CAUSE
#         lbonis1    #morethanmedicine SOCIAL_CAUSE
#         lbonis1     morethanmedicine SOCIAL_CAUSE
#   lizianerigelo    #MorethanMedicine SOCIAL_CAUSE
#   lizianerigelo     MorethanMedicine SOCIAL_CAUSE
#     lordbyronaf    #morethanmedicine SOCIAL_CAUSE
#     lordbyronaf     morethanmedicine SOCIAL_CAUSE
#       luapppank    #MoreThanMedicine SOCIAL_CAUSE
#       luapppank     MoreThanMedicine SOCIAL_CAUSE
#     margolenko1    #MorethanMedicine SOCIAL_CAUSE
#     margolenko1        #animalhealth SOCIAL_CAUSE
#     margolenko1     MorethanMedicine SOCIAL_CAUSE
# mariannaurszula    #MorethanMedicine SOCIAL_CAUSE
# mariannaurszula        #animalhealth SOCIAL_CAUSE
# mariannaurszula     MorethanMedicine SOCIAL_CAUSE
#     melodyclegg    #MorethanMedicine SOCIAL_CAUSE
#     melodyclegg        #animalhealth SOCIAL_CAUSE
#     melodyclegg     MorethanMedicine SOCIAL_CAUSE
# mitchellsmartin    #MorethanMedicine SOCIAL_CAUSE
# mitchellsmartin     MorethanMedicine SOCIAL_CAUSE
#  mizuhomorrison    #MoreThanMedicine SOCIAL_CAUSE
#  mizuhomorrison     MoreThanMedicine SOCIAL_CAUSE
#  mottagiuseppe1        #AnimalHealth SOCIAL_CAUSE
#  mottagiuseppe1    #MorethanMedicine SOCIAL_CAUSE
#  mottagiuseppe1        #animalhealth SOCIAL_CAUSE
#  mottagiuseppe1     MorethanMedicine SOCIAL_CAUSE
#      mrsquintas    #MorethanMedicine SOCIAL_CAUSE
#      mrsquintas     MorethanMedicine SOCIAL_CAUSE
#      museumofpr    #morethanmedicine SOCIAL_CAUSE
#      museumofpr     morethanmedicine SOCIAL_CAUSE
#        muthunag    #MoreThanMedicine SOCIAL_CAUSE
#        muthunag     MoreThanMedicine SOCIAL_CAUSE
#      piratP1974    #MorethanMedicine SOCIAL_CAUSE
#      piratP1974        #animalhealth SOCIAL_CAUSE
#      piratP1974     MorethanMedicine SOCIAL_CAUSE
#   ricki_ifferte    #morethanmedicine SOCIAL_CAUSE
#   ricki_ifferte     morethanmedicine SOCIAL_CAUSE
#     rita2018arg    #MorethanMedicine SOCIAL_CAUSE
#     rita2018arg     MorethanMedicine SOCIAL_CAUSE
#    roxanefeller        #AnimalHealth SOCIAL_CAUSE
#    roxanefeller    #MorethanMedicine SOCIAL_CAUSE
#    roxanefeller        #animalhealth SOCIAL_CAUSE
#    roxanefeller #animalhealthmatters SOCIAL_CAUSE
#    roxanefeller    #morethanmedicine SOCIAL_CAUSE
#    roxanefeller     Animal medicines SOCIAL_CAUSE
#    roxanefeller     MorethanMedicine SOCIAL_CAUSE
#    roxanefeller     morethanmedicine SOCIAL_CAUSE
#     seers_helen    #morethanmedicine SOCIAL_CAUSE
#     seers_helen     morethanmedicine SOCIAL_CAUSE
#       shollavet    #MorethanMedicine SOCIAL_CAUSE
#       shollavet     MorethanMedicine SOCIAL_CAUSE
#        somedocs    #MoreThanMedicine SOCIAL_CAUSE
#        somedocs     MoreThanMedicine SOCIAL_CAUSE
#   stephsteeves7    #MorethanMedicine SOCIAL_CAUSE
#   stephsteeves7        #animalhealth SOCIAL_CAUSE
#   stephsteeves7     MorethanMedicine SOCIAL_CAUSE
#         subee91    #MoreThanMedicine SOCIAL_CAUSE
#         subee91     MoreThanMedicine SOCIAL_CAUSE
#   taylorbarbosa    #MorethanMedicine SOCIAL_CAUSE
#   taylorbarbosa        #animalhealth SOCIAL_CAUSE
#   taylorbarbosa     MorethanMedicine SOCIAL_CAUSE
#        timocity    #MoreThanMedicine SOCIAL_CAUSE
#        timocity     MoreThanMedicine SOCIAL_CAUSE
# tomitaltosai022    #MorethanMedicine SOCIAL_CAUSE
# tomitaltosai022        #animalhealth SOCIAL_CAUSE
# tomitaltosai022     MorethanMedicine SOCIAL_CAUSE
#        wameyokw    #MorethanMedicine SOCIAL_CAUSE
#        wameyokw        #animalhealth SOCIAL_CAUSE
#        wameyokw     MorethanMedicine SOCIAL_CAUSE
#        wameyokw       animal welfare SOCIAL_CAUSE
# wegetittogether    #morethanmedicine SOCIAL_CAUSE
# wegetittogether     morethanmedicine SOCIAL_CAUSE
#        welshted    #morethanmedicine SOCIAL_CAUSE
#        welshted     morethanmedicine SOCIAL_CAUSE
#     wontarul277    #MorethanMedicine SOCIAL_CAUSE
#     wontarul277     MorethanMedicine SOCIAL_CAUSE
#               Author       Matched Text    Identifier
# 0            ACEPNow  #MoreThanMedicine  SOCIAL_CAUSE
# 1            ACEPNow   MoreThanMedicine  SOCIAL_CAUSE
# 2           ACNANSI1  #MorethanMedicine  SOCIAL_CAUSE
# 3           ACNANSI1   MorethanMedicine  SOCIAL_CAUSE
# 4           ACOEPRSO  #MoreThanMedicine  SOCIAL_CAUSE
# ..               ...                ...           ...
# 385  wegetittogether   morethanmedicine  SOCIAL_CAUSE
# 386         welshted  #morethanmedicine  SOCIAL_CAUSE
# 387         welshted   morethanmedicine  SOCIAL_CAUSE
# 388      wontarul277  #MorethanMedicine  SOCIAL_CAUSE
# 389      wontarul277   MorethanMedicine  SOCIAL_CAUSE
#
# [390 rows x 3 columns]

# %% [markdown]
# ##### Initially I was following the example in the Social Cause from blackboard, and it wasn't returning any results, but I realize now that the CSV we are using isn't about any of that stuff at all, but I just refit the code for the #morethanmedicine tags. Which because of the hashtag in every item of the CSV doc we do return each tweet essentially, oops! But it just means it is positively identifying one of our phrases in the dataframe we created to search for! Which is great and what we are looking for with PhraseMatcher. The matcher with REGEX is capturing variations of the hashtag regardless of capitalization. Lemmatization is also matching with related concepts like "animal" + "health/welfare" even with varied phrasing. The on_match callback is ensuring we get a structured extraction with author attribution, to make a nice and pretty table presentation from the data as well.
#
# ##### I thought this was pretty interesting, I like that we get to see how language relates to each other and can further encapsulate specific phrasing, to essentially cast a wider net and help narrow the focus or draw in what we are looking for specifically. It can help to ensure the data that has been compiled all fit and are useful for a specific purpose which would ensure we have relevent data compiled. Similar to if we were looking for specific e-mails in a server and wanted to directly query out information regarding sales, but from the company wide perspective, and were looking for key phrasing. Or if you were looking to see if there were any mentions of high level security in government capacities. Very fun to look into and see the output. Now that I'm thinking about it, there's more data points than the actual document, and I think it is hitting tweets more than once if it mentions one of the matchers/phrasematchers and is applying them to the end result, which is inflating the numbers and my answer before about it returning each tweet wasn't quite correct. That would make more sense, so this is printing each match each time, and not just once, but every instance is matches with. That's pretty interesting too!
#
# ##### Overall happy with how this weeks exercise turned out, and I'm excited for a little break, and I appreciate your feedback this term Professor Sloan! Have a great Thanksgiving and break! I hope to see you around!
